# %%
import numpy as np
import pandas as pd
import seaborn as sns
data = pd.read_csv('/content/train.csv.zip')
df = pd.DataFrame(data)
df.head()
df.sample(5)
# df.describe()
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 21725  0xb1c5      MYSRES20DEL02                   25                       5
# 44965  0xe034      GOARES16DEL01                   25                     4.9
# 24705  0x160e     INDORES03DEL02                   29                       4
# 37261  0x9104     PUNERES15DEL01                   28                     4.7
# 25119  0x1891      JAPRES04DEL01                   26                     4.8
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 21725            12.337978             76.616792                   12.357978
# 44965            15.498603             73.826911                   15.538603
# 24705            22.751857             75.866699                   22.801857
# 37261            18.636215             73.751081                   18.676215
# 25119            26.902328             75.794257                   26.912328
#
# ...

# %%
# df.info()
df.dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age             object
# Delivery_person_Ratings         object
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weatherconditions               object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries             object
# Festival                        object
# City                            object
# Time_taken(min)                 object
# dtype: object

# %%
df.isnull().sum().sum()
df.isna().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weatherconditions              0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken(min)                0
# dtype: int64

# %%
rows,cols = df.shape

# %%
df.sample(500)
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 38738  0xd21c     LUDHRES17DEL02                   21                     4.9
# 40162  0x2654     PUNERES03DEL02                   37                     4.3
# 41135   0x59e     MUMRES010DEL01                 NaN                     NaN
# 42554  0x33af      VADRES14DEL01                   37                     4.6
# 18547  0x6b50      MUMRES15DEL01                   26                     4.9
# ...        ...                ...                 ...                     ...
# 7085   0x581d      JAPRES08DEL03                   28                     3.6
# 7574   0x6427      VADRES03DEL03                   20                     4.8
# 31584  0xac61   RANCHIRES03DEL02                   22                     4.5
# 25720  0x93df     PUNERES16DEL02                   23                     4.2
# 27639  0x6889      HYDRES15DEL03                   28                     4.6
#
# ...

# %% [markdown]
# ##---------problem -------------NaN string value in data

# %%
df.loc[41135,"Delivery_person_Age"]
# Out:
# 'NaN '

# %%
(df == "NaN ").sum()
(df == "NaN ").sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weatherconditions              0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken(min)                0
# dtype: int64

# %%
df.replace("NaN ",np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions                 0
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
#NaN in whearther column
(
    df.loc[:,"Weatherconditions"]
    .str.contains("NaN")
    .sum()
)
# Out:
# np.int64(616)

# %%
df['Weatherconditions'] = df['Weatherconditions'].str.replace("conditions", "").str.strip()
df['Weatherconditions'] = df['Weatherconditions'].replace('NaN', np.nan)
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions               616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
df.loc[:,"Weatherconditions"].sample(60)
# Out:
# 32390         Windy
# 11023         Windy
# 37803         Sunny
# 43414    Sandstorms
# 45236         Windy
# 26738    Sandstorms
# 10498        Stormy
# 21400        Cloudy
# 42252         Windy
# 20823         Windy
# 41605        Stormy
# 38526         Windy
# 16912        Stormy
# 18243    Sandstorms
# 16282        Stormy
# 21615    Sandstorms
# 25479        Stormy
# 38276        Stormy
# 10640    Sandstorms
# 30293           Fog
# 4771         Cloudy
# 19195        Stormy
# 14195    Sandstorms
# 32609           Fog
# 44267        Cloudy
# 26215           Fog
# 22097        Cloudy
# 10027           NaN
# 9507          Sunny
# 30392    Sandstorms
# 7306         Cloudy
# 18880         Windy
# 44536        Stormy
# 7298          Windy
# 12333           Fog
# 23592        Cloudy
# 24336    Sandstorms
# 1912          Windy
# 29341           Fog
# 28219        Stormy
# 44485        Stormy
# 24531    Sandstorms
# 19598        Cloudy
# 7246          Sunny
# 39204         Sunny
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(9131)

# %% [markdown]
# missing value analysis

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %% [markdown]
# observation
# 1. delivery person cols are correalted each other this means it realted lack of rider data
# 2.

# %%
(df.isnull().any(axis=1).sum()/df.shape[0])*100
# Out:
# np.float64(9.266773408198627)

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# !git add README.md
# Out:
# fatal: pathspec 'README.md' did not match any files

# %%
# !git remote add origin https://github.com/SunilDhayal0/Swiggy-Delivery-Time-Prediction-Using-Machine-Learning.git

# %%
# !git branch -M main

# %%
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/SunilDhayal0/Swiggy-Delivery-Time-Prediction-Using-Machine-Learning.git'

# %%
# !git add .

# %%
# !git commit -m 'data cleaning'
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@f9f58b46bcf5.(none)')

# %%
# !git config --global user.name "Sunil Dhayal"
# !git config --global user.email "sunildhayal368@gmail.com"

# %%
# !git config --global user.name
# !git config --global user.email
# Out:
# Sunil Dhayal
# sunildhayal368@gmail.com

# %%
# !ls -
# Out:
# .  ..  .config	.git  sample_data  swiggy.csv  train.csv.zip
